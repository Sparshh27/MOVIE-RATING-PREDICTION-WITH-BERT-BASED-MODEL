# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertModel
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# Load BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertModel.from_pretrained('bert-base-uncased')

# %%
# Tokenize and convert text to embeddings
def get_embeddings(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    outputs = bert_model(**inputs)
    return outputs.pooler_output

# %%
# Load the data
movies = pd.read_csv('Dataset-100k/u.item', sep='|', encoding='latin-1', header=None, names=['movieId', 'title', 'release_date', 'video_release_date', 'imdb_url'] + list(range(19)))

ratings = pd.read_csv('Dataset-100k/u.data', sep='\t', header=None, names=['userId', 'movieId', 'rating', 'timestamp'])

# Merge datasets
data = pd.merge(ratings, movies[['movieId', 'title']], on='movieId')

# Split the data into train and test sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# %%
# Model architecture
class RatingPredictor(nn.Module):
    def __init__(self, input_size):
        super(RatingPredictor, self).__init__()
        self.fc = nn.Linear(input_size, 1)

    def forward(self, x):
        return self.fc(x)

# Hyperparameters
input_size = 768  # Size of BERT embeddings
lr = 0.001
epochs = 5

# Rating Predictor Model, Loss, Optimizer
rating_predictor_model = RatingPredictor(input_size)
criterion = nn.MSELoss()
optimizer = optim.Adam(rating_predictor_model.parameters(), lr=lr)

# %%
# Training loop for 200 iterations- can be extended to the whole dataset
max_iterations = 200
for epoch in range(epochs):
    total_loss = 0.0
    for i, (_, row) in enumerate(train_data.iterrows()):
        text = row['title']
        rating = row['rating']

        # Tokenization and embedding
        embedding = get_embeddings(text)

        # Forward pass
        output = rating_predictor_model(embedding)
        loss = criterion(output, torch.tensor([[rating]], dtype=torch.float))

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        # Break the loop if we reach the specified number of iterations
        if i == max_iterations - 1:
            break

    # Print the average loss for this epoch
    print(f"Epoch {epoch + 1}/{epochs}, Average Loss: {total_loss / len(train_data)}")

    # Break the outer loop if we reach the specified number of iterations
    if i == max_iterations - 1:
        break

# %%
# Evaluation
rating_predictor_model.eval()
predictions = []
labels = []

# Limit the evaluation loop to 200 iterations for testing
max_eval_iterations = 200
for i, (_, row) in enumerate(test_data.iterrows()):
    text = row['title']
    rating = row['rating']

    # Tokenization and embedding
    embedding = get_embeddings(text)

    # Prediction
    output = rating_predictor_model(embedding)
    predictions.append(output.item())
    labels.append(rating)

    # Break the loop if we reach the specified number of iterations
    if i == max_eval_iterations - 1:
        break

# Print predictions and labels during evaluation
for pred, label in zip(predictions, labels):
    print(f"Prediction: {pred}, Label: {label}")

# %%
# Calculate RMSE
rmse = ((torch.tensor(predictions) - torch.tensor(labels)) ** 2).mean().sqrt()
print(f"RMSE: {rmse}")
# Out:
# Epoch 1/5, Average Loss: 0.003368861171678262
# Prediction: 3.3546266555786133, Label: 3
# Prediction: 3.451507568359375, Label: 5
# Prediction: 3.2526540756225586, Label: 4
# Prediction: 3.448939323425293, Label: 3
# Prediction: 3.1001851558685303, Label: 3
# Prediction: 3.4318535327911377, Label: 4
# Prediction: 3.4206299781799316, Label: 4
# Prediction: 3.268927812576294, Label: 1
# Prediction: 3.4649946689605713, Label: 4
# Prediction: 3.4651589393615723, Label: 4
# Prediction: 3.3941872119903564, Label: 5
# Prediction: 3.4022653102874756, Label: 4
# Prediction: 3.310976505279541, Label: 3
# Prediction: 3.0886828899383545, Label: 4
# Prediction: 3.2893385887145996, Label: 2
# Prediction: 3.4471991062164307, Label: 3
# Prediction: 3.4144036769866943, Label: 5
# Prediction: 3.477458953857422, Label: 5
# Prediction: 3.215217113494873, Label: 3
# Prediction: 3.4388082027435303, Label: 2
# Prediction: 3.477344512939453, Label: 4
# Prediction: 3.425541877746582, Label: 3
# Prediction: 3.2217655181884766, Label: 4
# Prediction: 3.4452433586120605, Label: 3
# Prediction: 3.471980571746826, Label: 5
# Prediction: 3.421203851699829, Label: 3
# Prediction: 3.5160086154937744, Label: 1
# Prediction: 3.4047069549560547, Label: 4
# Prediction: 3.4088833332061768, Label: 5
# Prediction: 3.4029526710510254, Label: 2
# Prediction: 3.4773108959198, Label: 3
# Prediction: 3.4613780975341797, Label: 5
# Prediction: 3.4671268463134766, Label: 5
# Prediction: 3.364227533340454, Label: 4
# Prediction: 3.4269864559173584, Label: 3
# Prediction: 3.319943428039551, Label: 4
# Prediction: 3.552449941635132, Label: 4
# Prediction: 3.360609769821167, Label: 3
# Prediction: 3.2700467109680176, Label: 4
# Prediction: 3.3616623878479004, Label: 4
# Prediction: 3.2526540756225586, Label: 4
# Prediction: 3.3730223178863525, Label: 4
# Prediction: 3.358600378036499, Label: 4
# Prediction: 3.425922393798828, Label: 3
# Prediction: 3.4678661823272705, Label: 4
# Prediction: 3.2981345653533936, Label: 4
# Prediction: 3.406674385070801, Label: 2
# Prediction: 3.4514875411987305, Label: 3
# Prediction: 3.474242687225342, Label: 3
# Prediction: 3.389127254486084, Label: 4
# Prediction: 3.4970006942749023, Label: 4
# Prediction: 3.50055193901062, Label: 4
# Prediction: 3.4128050804138184, Label: 3
# Prediction: 3.4035122394561768, Label: 3
# Prediction: 3.447415590286255, Label: 3
# Prediction: 3.3767762184143066, Label: 5
# Prediction: 3.469058036804199, Label: 1
# Prediction: 3.250192642211914, Label: 4
# Prediction: 3.4359519481658936, Label: 3
# Prediction: 3.490483522415161, Label: 3
# Prediction: 3.4298977851867676, Label: 4
# Prediction: 3.4382338523864746, Label: 5
# Prediction: 3.446411371231079, Label: 2
# Prediction: 3.4503018856048584, Label: 5
# Prediction: 3.324859142303467, Label: 5
# Prediction: 3.501854181289673, Label: 4
# Prediction: 3.4288082122802734, Label: 4
# Prediction: 3.4393067359924316, Label: 5
# Prediction: 3.3934779167175293, Label: 3
# Prediction: 3.4361844062805176, Label: 2
# Prediction: 3.490483522415161, Label: 5
# Prediction: 3.435554027557373, Label: 3
# Prediction: 3.446920394897461, Label: 4
# Prediction: 3.5296261310577393, Label: 5
# Prediction: 3.4374163150787354, Label: 5
# Prediction: 3.48406982421875, Label: 5
# Prediction: 3.4760000705718994, Label: 4
# Prediction: 3.205172061920166, Label: 3
# Prediction: 3.4595727920532227, Label: 3
# Prediction: 3.387211561203003, Label: 5
# Prediction: 3.2087864875793457, Label: 4
# Prediction: 3.432293653488159, Label: 4
# Prediction: 3.455198049545288, Label: 3
# Prediction: 3.4388082027435303, Label: 4
# Prediction: 3.4634902477264404, Label: 3
# Prediction: 3.384165048599243, Label: 3
# Prediction: 3.3653368949890137, Label: 3
# Prediction: 3.4212982654571533, Label: 1
# Prediction: 3.3966171741485596, Label: 4
# Prediction: 3.4389142990112305, Label: 3
# Prediction: 3.4375436305999756, Label: 3
# Prediction: 3.329561471939087, Label: 3
# Prediction: 3.4269864559173584, Label: 3
# Prediction: 3.2526540756225586, Label: 4
# Prediction: 3.356574296951294, Label: 4
# Prediction: 3.356574296951294, Label: 3
# Prediction: 3.4304990768432617, Label: 5
# Prediction: 3.18735933303833, Label: 1
# Prediction: 3.3412890434265137, Label: 4
# Prediction: 3.271583318710327, Label: 2
# Prediction: 3.415259599685669, Label: 3
# Prediction: 3.3032562732696533, Label: 2
# Prediction: 3.4510252475738525, Label: 3
# Prediction: 3.462329626083374, Label: 5
# Prediction: 3.4315028190612793, Label: 4
# Prediction: 3.3932271003723145, Label: 3
# Prediction: 3.446002244949341, Label: 5
# Prediction: 3.3598239421844482, Label: 2
# Prediction: 3.4609196186065674, Label: 3
# Prediction: 3.4089388847351074, Label: 3
# Prediction: 3.4052751064300537, Label: 3
# Prediction: 3.4926886558532715, Label: 3
# Prediction: 3.3788228034973145, Label: 3
# Prediction: 3.442200183868408, Label: 3
# Prediction: 3.250192642211914, Label: 4
# Prediction: 3.447138547897339, Label: 5
# Prediction: 3.462597131729126, Label: 4
# Prediction: 3.395397186279297, Label: 3
# Prediction: 3.4310317039489746, Label: 3
# Prediction: 3.4777779579162598, Label: 1
# Prediction: 3.4156322479248047, Label: 5
# Prediction: 3.4757113456726074, Label: 4
# Prediction: 3.3682925701141357, Label: 3
# Prediction: 3.4260244369506836, Label: 4
# Prediction: 3.418731212615967, Label: 5
# Prediction: 3.438385486602783, Label: 4
# Prediction: 3.501854181289673, Label: 4
# Prediction: 3.459026336669922, Label: 4
# Prediction: 3.4802889823913574, Label: 5
# Prediction: 3.40779447555542, Label: 5
# Prediction: 3.4606809616088867, Label: 5
# Prediction: 3.4258790016174316, Label: 3
# Prediction: 3.4417850971221924, Label: 5
# Prediction: 3.3767762184143066, Label: 1
# Prediction: 3.4572699069976807, Label: 5
# Prediction: 3.424851417541504, Label: 3
# Prediction: 3.3993260860443115, Label: 5
# Prediction: 3.4342076778411865, Label: 2
# Prediction: 3.4039509296417236, Label: 2
# Prediction: 3.492027997970581, Label: 5
# Prediction: 3.492027997970581, Label: 4
# Prediction: 3.4269864559173584, Label: 5
# Prediction: 3.4631497859954834, Label: 3
# Prediction: 3.4180047512054443, Label: 4
# Prediction: 3.4378514289855957, Label: 1
# Prediction: 3.34906005859375, Label: 2
# Prediction: 3.2781713008880615, Label: 4
# Prediction: 3.3951635360717773, Label: 1
# Prediction: 3.4400298595428467, Label: 4
# Prediction: 3.4277186393737793, Label: 4
# Prediction: 3.387117862701416, Label: 3
# Prediction: 3.324296474456787, Label: 3
# Prediction: 3.2853736877441406, Label: 3
# Prediction: 3.3198812007904053, Label: 4
# Prediction: 3.2811732292175293, Label: 3
# Prediction: 3.412053346633911, Label: 3
# Prediction: 3.3598239421844482, Label: 5
# Prediction: 3.4512200355529785, Label: 2
# Prediction: 3.550743579864502, Label: 2
# Prediction: 3.4759914875030518, Label: 5
# Prediction: 3.4428670406341553, Label: 4
# Prediction: 3.5092668533325195, Label: 5
# Prediction: 3.4031150341033936, Label: 4
# Prediction: 3.4147958755493164, Label: 4
# Prediction: 3.3164539337158203, Label: 4
# Prediction: 3.337400197982788, Label: 3
# Prediction: 3.164720058441162, Label: 5
# Prediction: 3.4323973655700684, Label: 3
# Prediction: 3.4461348056793213, Label: 2
# Prediction: 3.4375436305999756, Label: 3
# Prediction: 3.354498863220215, Label: 5
# Prediction: 3.301823616027832, Label: 5
# Prediction: 3.4157874584198, Label: 1
# Prediction: 3.5336971282958984, Label: 1
# Prediction: 3.3412890434265137, Label: 4
# Prediction: 3.4397904872894287, Label: 1
# Prediction: 3.447866201400757, Label: 4
# Prediction: 3.3243918418884277, Label: 5
# Prediction: 3.386691093444824, Label: 4
# Prediction: 3.3441505432128906, Label: 5
# Prediction: 3.4760000705718994, Label: 3
# Prediction: 3.5291829109191895, Label: 1
# Prediction: 3.3475725650787354, Label: 3
# Prediction: 3.18735933303833, Label: 4
# Prediction: 3.37900447845459, Label: 5
# Prediction: 3.4585018157958984, Label: 4
# Prediction: 3.334564208984375, Label: 4
# Prediction: 3.3771095275878906, Label: 3
# Prediction: 3.484503746032715, Label: 4
# Prediction: 3.4312891960144043, Label: 5
# Prediction: 3.1742146015167236, Label: 3
# Prediction: 3.4035913944244385, Label: 1
# Prediction: 3.4684300422668457, Label: 3
# Prediction: 3.2526540756225586, Label: 3
# Prediction: 3.4388082027435303, Label: 4
# Prediction: 3.4360029697418213, Label: 1
# Prediction: 3.4660844802856445, Label: 5
# Prediction: 3.3951635360717773, Label: 5
# Prediction: 3.435554027557373, Label: 4
# Prediction: 3.2624599933624268, Label: 5
# RMSE: 1.1493929624557495
